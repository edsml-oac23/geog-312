# %% [markdown]
# # Looping and Control Statements
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/geog-312/blob/main/book/python/05_looping.ipynb)
#
# ## Overview
#
# This lecture introduces looping and control statements in Python, focusing on their applications in geospatial programming. Loops and control statements are essential tools for automating repetitive tasks, making decisions based on data conditions, and efficiently processing large geospatial datasets. By mastering these concepts, you will be able to handle complex geospatial analysis tasks with greater efficiency and precision.
#
# ## Learning Objectives
#
# By the end of this lecture, you should be able to:
#
# - Understand and implement `for` loops to iterate over sequences such as lists and tuples.
# - Use `while` loops to perform tasks until a specific condition is met.
# - Apply control statements (`if`, `elif`, `else`) to execute different blocks of code based on data conditions.
# - Combine loops and control statements to filter, process, and analyze geospatial data.
# - Develop the ability to automate repetitive geospatial tasks, making your data processing workflows more efficient.
#
# ## For Loops
#
# For loops allow you to iterate over a sequence (such as a list, tuple, or string) and execute a block of code for each item in the sequence. This is particularly useful in geospatial programming when you need to process multiple features or coordinates.

# %%
coordinates = [
    (35.6895, 139.6917),
    (34.0522, -118.2437),
    (51.5074, -0.1278),
]  # List of tuples representing coordinates

for lat, lon in coordinates:
    print(f"Latitude: {lat}, Longitude: {lon}")

# %% [markdown]
# Assuming you have a function to calculate distances, you can use a loop to compute distances from a reference point.

# %%
def calculate_distance(lat1, lon1, lat2, lon2):
    # Placeholder for distance calculation logic
    return ((lat2 - lat1) ** 2 + (lon2 - lon1) ** 2) ** 0.5


reference_point = (0, 0)  # Reference point (latitude, longitude)

for lat, lon in coordinates:
    distance = calculate_distance(reference_point[0], reference_point[1], lat, lon)
    print(f"Distance from {reference_point} to ({lat}, {lon}): {distance:.2f}")

# %% [markdown]
# ## While Loops
#
# While loops continue to execute a block of code as long as a specified condition is true. They are useful when the number of iterations is not known beforehand, such as when processing data until a certain condition is met.

# %%
counter = 0
while counter < len(coordinates):
    lat, lon = coordinates[counter]
    print(f"Processing coordinate: ({lat}, {lon})")
    counter += 1

# %% [markdown]
# ## Control Statements: if, elif, else
#
# Control statements allow you to execute different blocks of code based on certain conditions. In geospatial programming, this is useful for handling different types of data or conditions.

# %%
for lat, lon in coordinates:
    if lat > 0:
        print(f"{lat} is in the Northern Hemisphere")
    elif lat < 0:
        print(f"{lat} is in the Southern Hemisphere")
    else:
        print(f"{lat} is near the equator")

# %% [markdown]
# You can further categorize based on longitude:

# %%
for lat, lon in coordinates:
    if lat > 0:
        hemisphere = "Northern"
    else:
        hemisphere = "Southern"

    if lon > 0:
        direction = "Eastern"
    else:
        direction = "Western"

    print(
        f"The coordinate ({lat}, {lon}) is in the {hemisphere} Hemisphere and {direction} Hemisphere."
    )

# %% [markdown]
# ## Combining Loops and Control Statements
#
# You can combine loops and control statements to perform more complex operations, such as filtering data or applying conditions during iteration.

# %%
filtered_coordinates = []
for lat, lon in coordinates:
    if lon > 0:
        filtered_coordinates.append((lat, lon))
print(f"Filtered coordinates (only with positive longitude): {filtered_coordinates}")

# %%
southern_count = 0
for lat, lon in coordinates:
    if lat < 0:
        southern_count += 1
print(f"Number of coordinates in the Southern Hemisphere: {southern_count}")

# %% [markdown]
# ## Exercises
#
# 1. Create a list of cities with their coordinates. Write a for loop to print out only the cities that are in the Northern Hemisphere.
# 2. Write a while loop that continues to print the coordinates in a list until a coordinate with a latitude less than 0 is found.
# 3. Create a for loop that iterates through a list of coordinates and prints whether each coordinate is in the Eastern or Western Hemisphere based on the longitude.
# 4. Combine a for loop and if statements to count how many coordinates in a list are located in the Southern Hemisphere.
# 5. Write a program that generates random coordinates (latitude and longitude) and prints them until a coordinate with both latitude and longitude greater than 50 is generated.

# %% [markdown]
# ## Summary
#
# Loops and control statements are fundamental tools in geospatial programming. They allow you to process and analyze geographic data efficiently by automating repetitive tasks and applying logic based on data conditions. Practice these concepts by applying them to your geospatial datasets and analyses.

# %% [markdown]
# MY TESTS

# %%
coordinates = [
(35.3434,2.234234),
(34.23432,2.23423),
(45.34545,56.34342)
]

for lat , long in coordinates:
    print(lat, long)
# Out:
# 35.3434 2.234234
# 34.23432 2.23423
# 45.34545 56.34342

# %%
coordinates = [
(35.3434,2.234234),
(34.23432,2.23423),
(-89.879,56.34342)
]

for lat , long in coordinates:
    print(f' Latitude: {lat}, Longitude {long}')
# Out:
#  Latitude: 35.3434, Longitude 2.234234
#  Latitude: 34.23432, Longitude 2.23423
#  Latitude: -89.879, Longitude 56.34342

# %%
def calculate_distance(lat1, lat2, lon1, lon2):
    return ((lat2-lat1)**2 +(lon2-lon1)**2)** 0.5

# %%
reference_point = (0,0)
for lat, lon in coordinates:
    distance = calculate_distance(reference_point[0], reference_point[1], lat, lon)
    print(f"Distance from {reference_point} to ({lat}, {lon}) is : {distance:.3f}")
# Out:
# Distance from (0, 0) to (35.3434, 2.234234) is : 33.109
# Distance from (0, 0) to (34.23432, 2.23423) is : 32.000
# Distance from (0, 0) to (45.34545, 56.34342) is : 10.998

# %%
cities= ["new york", "quito", "cuenca", "london", "paris"]
print("cities of the world")
for i , city in enumerate(cities):
    print(f' {i+1}. {city.capitalize()}')
# Out:
# cities of the world
#  1. New york
#  2. Quito
#  3. Cuenca
#  4. London
#  5. Paris

# %%
len (coordinates)
# Out:
# 3

# %%
coordinates
# Out:
# [(35.3434, 2.234234), (34.23432, 2.23423), (45.34545, 56.34342)]

# %%
counter = 2

while counter < len(coordinates):
    lat, lon = coordinates[counter]
    print(f'processing coordinate: {lat} , {lon}')
    counter +=1
# Out:
# processing coordinate: 45.34545 , 56.34342

# %%
import random

# %%
target_latitude = 40.0
tolerance = 0.1
attemps = 0
max_attempts = 10
print("------" *6)
print(f'searching coordinates near latitude , {target_latitude}')
print("------" *6)

while attemps < max_attempts:
    rand_lat = random.uniform(35.0 , 45.0)
    rand_lon = random.uniform(79.98 , 86.36)
    print (f'random latitude is {rand_lat}')
    print(f'random longiude is {rand_lon}')
    attemps += 1
    print("*" * 6)
    if abs(rand_lat - target_latitude) <= tolerance:
        print(f'target latitude founded within the tolerance. Target is {target_latitude} and found latitude is {rand_lat}')
    print(f'coordinate found {rand_lat}')
# Out:
# ------------------------------------
# searching coordinates near latitude , 40.0
# ------------------------------------
# random latitude is 37.92631702391346
# random longiude is 80.98507038504789
# ******
# coordinate found 37.92631702391346
# random latitude is 39.12375694246186
# random longiude is 81.93756605396234
# ******
# coordinate found 39.12375694246186
# random latitude is 36.709343322233366
# random longiude is 84.60342462420158
# ******
# coordinate found 36.709343322233366
# random latitude is 36.14538791201991
# random longiude is 86.27054002196351
# ******
# coordinate found 36.14538791201991
# random latitude is 41.468590474950275
# random longiude is 82.86755394227045
# ******
# coordinate found 41.468590474950275
# random latitude is 43.634725623742625
# random longiude is 81.15435383208039
# ******
# coordinate found 43.634725623742625
# random latitude is 37.69600784056005
# random longiude is 86.32405647576604
# ******
# coordinate found 37.69600784056005
# random latitude is 41.09067716943121
# random longiude is 80.18293036093264
# ******
# coordinate found 41.09067716943121
# random latitude is 36.78793151914358
# random longiude is 80.70391449599347
# ******
# coordinate found 36.78793151914358
# random latitude is 41.52538133651148
# random longiude is 81.28343531055305
# ******
# coordinate found 41.52538133651148

# %%
coordinates
# Out:
# [(35.3434, 2.234234), (34.23432, 2.23423), (0, 56.34342)]

# %%
for lat , lon in coordinates:
    if lat > 0:
        print(f'{lat} is in the Northern H. It only executes this first conditional')
    elif lat < 0:
        print(f"{lat} is in the sourthern H")
    else:
        print(f'lat is in the ecuator {lat}')
# Out:
# 35.3434 is in the Northern H. It only executes this first conditional
# 34.23432 is in the Northern H. It only executes this first conditional
# lat is in the ecuator 0

# %%
for lat, lon in coordinates:
    if lat >0:
        hemisphere = "northern"
    else:
        hemisphere = "southern"
    if lon > 0:
        direction = "eastern"
    else:
        direction = "western"
    
print(f'the ({lat} ; {lon}) coordinates are in the "{hemisphere}" Hemisphere and in the "{direction}" Hemisphere')
# Out:
# the (0 ; 56.34342) coordinates are in the "southern" Hemisphere and in the "eastern" Hemisphere

# %%
for lat , lon in coordinates:
    if lat > 0 and lon > 0:
        quadrant = "northeast"
    elif lat > 0 and lon < 0 :
        quandrant = "northwest"
    elif lat < 0 and lon > 0:
        quadrant = "southeast"
    else:
        quadrant = "shouthwest" 

    print (f' the coordinates ({lat} ; {lon}) are in the {quadrant} quadrant')
# Out:
#  the coordinates (35.3434 ; 2.234234) are in the northeast quadrant
#  the coordinates (34.23432 ; 2.23423) are in the northeast quadrant
#  the coordinates (-89.879 ; 56.34342) are in the southeast quadrant

# %%
filtered_coordinates = []
for lat, lon in coordinates:
    if lat > 0:
        filtered_coordinates.append((lat,lon))
print(f' filtered positive coordinates {filtered_coordinates}')
# Out:
#  filtered positive coordinates [(35.3434, 2.234234), (34.23432, 2.23423)]

# %%
southern_count = 0
for lat, lon in coordinates:
    if lat < 0 :
        southern_count += 1

print (f' the number of negative latitudes are: {southern_count}')
# Out:
#  the number of negative latitudes are: 1

# %%
hasattr(southern_count, "__iter__")
# Out:
# False

# %%
analysis_coordinates = [
(40.7128, -74.0060),  # New York
(-33.8688, 500),  # Sydney
(51.5074, -0.1278),  # London
(-1.2921, 36.8219),  # Nairobi
(35.6762, 139.6503),  # Tokyo
]

# %%
valid_coordinates = []
northern_count = 0
eastern_count= 0
southern_count = 0
western_count = 0

print ("Coordinate analysis")
print("-"*60)
for lat, lon in analysis_coordinates:
    if  -90 <= lat <= 90 and -180 <= lon <= 180:
        valid_coordinates.append((lat, lon))
        if lat >= 0:
            northern_count += 1
        else: 
            southern_count +=1
        if lon >=0:
            eastern_count +=1
        else:
            western_count +=1
        print(valid_coordinates)
    else:
        print (f"coordinates {lat} ; {lon} are out or range")
print(f'count of coordinates in norhhern {northern_count}')
print(f'count of coordinates in norhhern {southern_count}')
print(f'count of coordinates in eastern {eastern_count}')
print(f'count of coordinates in norhhern {western_count}')
# Out:
# Coordinate analysis
# ------------------------------------------------------------
# [(40.7128, -74.006)]
# coordinates -33.8688 ; 500 are out or range
# [(40.7128, -74.006), (51.5074, -0.1278)]
# [(40.7128, -74.006), (51.5074, -0.1278), (-1.2921, 36.8219)]
# [(40.7128, -74.006), (51.5074, -0.1278), (-1.2921, 36.8219), (35.6762, 139.6503)]
# count of coordinates in norhhern 3
# count of coordinates in norhhern 1
# count of coordinates in eastern 2
# count of coordinates in norhhern 2
