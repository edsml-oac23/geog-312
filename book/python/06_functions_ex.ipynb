# %%
def add (a,b):
    return a+b

result = add (5,4)
print (result)
# Out:
# 9

# %%
def substract (a, b ,c ):
    return (a-b-c)
result2 = substract (4,2,-2)
print(result2)
# Out:
# 4

# %%
def greet (name, greeting= "Hi"):
    return (name, greeting)

# %%
person = greet ("Alice", "ji")
print (person)
# Out:
# ('Alice', 'ji')

# %%
def multiply (a, b):
    return a*b

result = multiply (3,5)
print (result)
# Out:
# 15

# %%
print("")
